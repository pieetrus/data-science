# %% [markdown]
# <a href="https://colab.research.google.com/github/pieetrus/data-science/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nowa sekcja

# %%
print('Hello Colab')
# Out:
# Hello Colab

# %%
print('Heloo')
# Out:
# Heloo
